# %%
import sys
sys.path += ['/user_data/vicky/CoEvo']

# %% [markdown]
# ---

# %%
from modules.display_result.extract.blocks.extractor import get_result

get_result()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from modules.display_result.extract.extract import get_result
#       3 get_result()
#
# ModuleNotFoundError: No module named 'modules'
